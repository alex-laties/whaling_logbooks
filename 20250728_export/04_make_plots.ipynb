# %%
import pandas as pd, numpy as np, os

current_directory = os.getcwd()
Figures = os.path.join(current_directory, 'manuscript_figures')
CSV = os.path.join(current_directory, 'CSV_files')
PKL = os.path.join(current_directory, 'PKL')

from utils.s_plots import plot_global, plot_decadal, plot_seasonal, plot_infill_boxplot_map, plot_infill_boxplot_map_split, plot_annual_distribution

# %%
#select your tier - all figures for the manuscript use tier 4
tier = 4

print(f"Loading Tier {tier} data...")
try:
    df = pd.read_pickle(os.path.join(PKL, f'Final_tier4_2025-08-26.pkl'))
    print("File loaded!")
except FileNotFoundError:
    print(f"Error: Tier{tier}.pkl' not found.")
# Out:
# Loading Tier 4 data...
# File loaded!

# %%
temp_df = df.copy()
df_coords = temp_df[temp_df["Latitude_decimal"].notna() & temp_df["Longitude_decimal"].notna()]
df_usable = df_coords[df_coords['Tier4_usable'] == True]

# %%
df_usable
# Out:
#             ID                     LogBook ID  Page  Entry Date Latitude  \
# 0         2442   A. Houghton (bark) 1853-1857   NaN  1853-07-06  37 51 N
# 1         2443   A. Houghton (bark) 1853-1857   NaN  1853-07-07  37 15 N
# 3         2446   A. Houghton (bark) 1853-1857   NaN  1853-07-09  33 45 N
# 4         2447   A. Houghton (bark) 1853-1857   NaN  1853-07-10  33 20 N
# 6         2449   A. Houghton (bark) 1853-1857   NaN  1853-07-12  33 49 N
# ...        ...                            ...   ...         ...      ...
# 121352  109169  Young Phenix (ship) 1836-1840   NaN  1840-12-12  39 06 N
# 121353  109170  Young Phenix (ship) 1836-1840   NaN  1840-12-13  38 35 N
# 121355  109172  Young Phenix (ship) 1836-1840   NaN  1840-12-15  38 25 N
# 121357  109174  Young Phenix (ship) 1836-1840   NaN  1840-12-17  38 55 N
# 121358  109175  Young Phenix (ship) 1836-1840   NaN  1840-12-18  38 55 N
#
#         Latitude_decimal Longitude  Longitude_decimal  Depth Depth Unit  ...  \
# 0              37.850000   58 28 W         -58.466667    NaN        NaN  ...
# 1              37.250000   55 04 W         -55.066667    NaN        NaN  ...
# 3              33.750000   52 28 W         -52.466667    NaN        NaN  ...
# 4              33.333333   53 43 W         -53.716667    NaN        NaN  ...
# 6              33.816667   53 04 W         -53.066667    NaN        NaN  ...
# ...                  ...       ...                ...    ...        ...  ...
# 121352         39.100000   70 00 W         -70.000000    NaN    fathoms  ...
# 121353         38.583333   68 18 W         -68.300000    NaN    fathoms  ...
# 121355         38.416667   65 38 W         -65.633333    NaN    fathoms  ...
# 121357         38.916667   57 20 W         -57.333333    NaN    fathoms  ...
# 121358         38.916667   56 33 W         -56.550000    NaN    fathoms  ...
#
#        usable gap_distance_km gap_days_missing gap_type  infill_days_missing  \
# 0        True             NaN              NaN      NaN                  NaN
# 1        True             NaN              NaN      NaN                  NaN
# 3        True             NaN              NaN      NaN                  NaN
# 4        True             NaN              NaN      NaN                  NaN
# 6        True             NaN              NaN      NaN                  NaN
# ...       ...             ...              ...      ...                  ...
# 121352   True             NaN              NaN      NaN                  NaN
# 121353   True             NaN              NaN      NaN                  NaN
# 121355   True             NaN              NaN      NaN                  NaN
# 121357   True             NaN              NaN      NaN                  NaN
# 121358   True             NaN              NaN      NaN                  NaN
#
#        infill_type  infill_distance_km Tier2_usable Tier3_usable Tier4_usable
# 0              NaN                 NaN         True         True         True
# 1              NaN                 NaN         True         True         True
# 3              NaN                 NaN         True         True         True
# 4              NaN                 NaN         True         True         True
# 6              NaN                 NaN         True         True         True
# ...            ...                 ...          ...          ...          ...
# 121352         NaN                 NaN         True         True         True
# 121353         NaN                 NaN         True         True         True
# 121355         NaN                 NaN         True         True         True
# 121357         NaN                 NaN         True         True         True
# 121358         NaN                 NaN         True         True         True
#
# [74384 rows x 41 columns]

# %%
plot_global(df_coords, df_usable, Figures, start_year=1820, end_year=1900, save=True)

# %%
plot_decadal(df_usable, Figures, start_decade=1820, end_decade=1900, save=True)
# Out:
# 1312
# 18349
# 24274
# 14147
# 6250
# 5659
# 3597
# 312

# %%
plot_seasonal(df_usable, Figures, save=True)
# Out:
# 19836
# 17873
# 17463
# 19212

# %%
19836 + 17873 + 17463 + 19212
# Out:
# 74384

# %%
plot_infill_boxplot_map(df, Figures, save=True)
# Out:
# n=5863
# n=2522
# n=1332
# n=836
# n=560

# %%
plot_infill_boxplot_map_split(df, Figures, save=True)

# %%
plot_annual_distribution(df_usable, Figures, start_year=1820, end_year=1900, save=True)
